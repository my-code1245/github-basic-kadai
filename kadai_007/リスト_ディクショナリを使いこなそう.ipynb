# %%
array=["月曜は晴れです","火曜日は雨です","水曜日は晴れです",'木曜日晴れです',"金曜日は曇りです","土曜日は曇りのうち雨です","日曜日は雷雨です",]

print(array[2])

dictinary={"mon":"晴れ","tue":"雨","web":"晴れ","thu":"晴れ","fri":"曇り","sat":"曇りのうち雨","sun":"雷雨"}

print(dictinary["web"])
# Out:
# 水曜日は晴れです
# 晴れ
