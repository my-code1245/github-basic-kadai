# %% [markdown]
# <a href="https://colab.research.google.com/github/my-code1245/github-basic-kadai/blob/main/%E7%B9%B0%E3%82%8A%E8%BF%94%E3%81%97%E5%87%A6%E7%90%86%E3%82%92%E4%BD%BF%E3%81%84%E3%81%93%E3%81%AA%E3%81%9D%E3%81%86.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
array = ["水","金","地","火","木","土","天","海","冥"]

for planet in array:
  print(planet)

i=0
while i<9:
  print(array[i])
  i = i+1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
